# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = "https://www.madlan.co.il/for-sale/רעננה-ישראל"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.content, 'html.parser')
if response.status_code == 200:
    print("success")
else:
    print(response.status_code)
# Out:
# success

# %%
def get_info():
    url = "https://www.madlan.co.il/for-sale/%D7%A8%D7%A2%D7%A0%D7%A0%D7%94-%D7%99%D7%A9%D7%A8%D7%90%D7%9C"
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    response = requests.get(url, headers = headers)
    
    #Initialize DataFrame
    df = pd.DataFrame(columns=['City', 'type', 'room_number', 'Area', 'Street', 'number_in_street', 'city_area', 'price'])
    try:
        if not response.status_code == 200:
            return df
        soup = BeautifulSoup(response.content, 'html.parser')
        type_list = list()
        room_number_list = list()
        Area_list = list()
        Street_info = list()
        price_list = list()
        
  
        
        for type_ in soup.find_all('div', {'data-auto': 'property-class', 'class': 'css-1i00gl6 e1sx3tzs17'}):
            type_list.append(type_.get_text())
            

        for room in soup.find_all('div', {'data-auto': 'property-rooms', 'class': 'css-1i00gl6 e1sx3tzs17'}):
            room_number_list.append(room.get_text())
            

        for area in soup.find_all('div', {'data-auto': 'property-size', 'class': 'css-1i00gl6 e1sx3tzs17'}):
            Area_list.append(area.get_text())
            

        for full_address in soup.find_all('div', {'data-auto': 'property-address', 'class': 'css-1i00gl6 e1sx3tzs17'}):
            Street_info.append(full_address.get_text()) 
         
        
        
        streets = []
        numbers = []
        city_areas = []

        for address in Street_info:
            # Extracting street using regex
            street_match = re.search(r'^([\w\s]+)', address)
            street = street_match.group(1).strip() if street_match else ""
            street = re.sub(r'\d+', '', street) if street else ""
            streets.append(street)

            # Extracting number in street using regex
            number_match = re.search(r'(\d+)', address)
            number = number_match.group(1).strip() if number_match else ""
            numbers.append(number)

            # Extracting city area using regex
            city_area_match = re.search(r'(?<=,)\s*([\w\s]+)$', address)
            city_area = city_area_match.group(1).strip() if city_area_match else ""
            city_areas.append(city_area)
            

            
            
        for price in soup.find_all('div', {'data-auto': 'property-price', 'class': 'css-1i00gl6 e1sx3tzs17'}):
            price_text = price.get_text()
            price_cut = price_text.strip()[:10]
            price_list.append(price_cut)
            
        
        df['City'] = "רעננה"
        df['type'] = type_list
        df['room_number'] = room_number_list
        df['Area'] = Area_list
        df['Street'] = streets
        df['number_in_street'] = numbers
        df['city_area'] = city_areas
        df['price'] = price_list

        return df
    except:
        return df

# %%
a=get_info()
a["City"] = "רעננה"
a
# Out:
#      City       type room_number     Area Street number_in_street city_area  \
# 0   רעננה       דירה       3 חד׳   90 מ"ר    NaN              NaN       NaN
# 1   רעננה       דירה       5 חד׳  150 מ"ר    NaN              NaN       NaN
# 2   רעננה      קוטג'       7 חד׳  265 מ"ר    NaN              NaN       NaN
# 3   רעננה      קוטג'       7 חד׳  260 מ"ר    NaN              NaN       NaN
# 4   רעננה       דירה       4 חד׳  100 מ"ר    NaN              NaN       NaN
# 5   רעננה       דירה       4 חד׳  103 מ"ר    NaN              NaN       NaN
# 6   רעננה   בית פרטי       2 חד׳   70 מ"ר    NaN              NaN       NaN
# 7   רעננה       דירה       4 חד׳   92 מ"ר    NaN              NaN       NaN
# 8   רעננה    דירת גג     6.5 חד׳  200 מ"ר    NaN              NaN       NaN
# 9   רעננה   בית פרטי     7.5 חד׳  280 מ"ר    NaN              NaN       NaN
# 10  רעננה     דופלקס       6 חד׳  168 מ"ר    NaN              NaN       NaN
# 11  רעננה   בית פרטי       9 חד׳  300 מ"ר    NaN              NaN       NaN
# 12  רעננה       דירה       5 חד׳  136 מ"ר    NaN              NaN       NaN
# 13  רעננה       דירה       5 חד׳  126 מ"ר    NaN              NaN       NaN
# 14  רעננה       דירה       4 חד׳  112 מ"ר    NaN              NaN       NaN
# 15  רעננה       דירה       5 חד׳  148 מ"ר    NaN              NaN       NaN
# 16  רעננה       דירה       4 חד׳   95 מ"ר    NaN              NaN       NaN
# 17  רעננה       דירה     4.5 חד׳  140 מ"ר    NaN              NaN       NaN
# 18  רעננה       דירה       5 חד׳  130 מ"ר    NaN              NaN       NaN
# 19  רעננה       דירה       6 חד׳  150 מ"ר    NaN              NaN       NaN
# 20  רעננה       דירה     3.5 חד׳   75 מ"ר    NaN              NaN       NaN
# 21  רעננה       דירה       5 חד׳  140 מ"ר    NaN              NaN       NaN
# 22  רעננה       דירה       4 חד׳  100 מ"ר    NaN              NaN       NaN
# 23  רעננה    דירת גן       5 חד׳  125 מ"ר    NaN              NaN       NaN
# 24  רעננה     דופלקס     5.5 חד׳  230 מ"ר    NaN              NaN       NaN
# 25  רעננה       דירה       4 חד׳  100 מ"ר    NaN              NaN       NaN
# 26  רעננה       דירה       5 חד׳  122 מ"ר    NaN              NaN       NaN
# 27  רעננה  דו משפחתי       5 חד׳  153 מ"ר    NaN              NaN       NaN
# 28  רעננה  דו משפחתי       8 חד׳  330 מ"ר    NaN              NaN       NaN
# 29  רעננה       דירה       5 חד׳  143 מ"ר    NaN              NaN       NaN
# 30  רעננה       דירה       4 חד׳  125 מ"ר    NaN              NaN       NaN
# 31  רעננה       דירה       4 חד׳  140 מ"ר    NaN              NaN       NaN
# 32  רעננה       דירה     4.5 חד׳  154 מ"ר    NaN              NaN       NaN
# 33  רעננה       דירה       4 חד׳  133 מ"ר    NaN              NaN       NaN
#
#    price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN

# %%
a.to_csv('output.csv', encoding='utf-8-sig', index=False)
